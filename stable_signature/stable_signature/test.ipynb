# %%
# %cd hidden
# Out:
# /raid/home/ashhar21137/watermarking3/stable_signature/hidden

# %%
import os 
os.environ["CUDA_VISIBLE_DEVICES"]='4'

# %%
import torch
from torchvision import transforms
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
from skimage.metrics import peak_signal_noise_ratio

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# you should run this notebook in the root directory of the hidden project for the following imports to work
# %cd ..
from models import HiddenEncoder, HiddenDecoder, EncoderWithJND, EncoderDecoder
from attenuations import JND

# %%
def msg2str(msg):
    return "".join([('1' if el else '0') for el in msg])

def str2msg(str):
    return [True if el=='1' else False for el in str]

# %%
class Params():
    def __init__(self, encoder_depth:int, encoder_channels:int, decoder_depth:int, decoder_channels:int, num_bits:int,
                attenuation:str, scale_channels:bool, scaling_i:float, scaling_w:float):
        # encoder and decoder parameters
        self.encoder_depth = encoder_depth
        self.encoder_channels = encoder_channels
        self.decoder_depth = decoder_depth
        self.decoder_channels = decoder_channels
        self.num_bits = num_bits
        # attenuation parameters
        self.attenuation = attenuation
        self.scale_channels = scale_channels
        self.scaling_i = scaling_i
        self.scaling_w = scaling_w

NORMALIZE_IMAGENET = transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
UNNORMALIZE_IMAGENET = transforms.Normalize(mean=[-0.485/0.229, -0.456/0.224, -0.406/0.225], std=[1/0.229, 1/0.224, 1/0.225])
default_transform = transforms.Compose([transforms.ToTensor(), NORMALIZE_IMAGENET])

params = Params(
    encoder_depth=4, encoder_channels=64, decoder_depth=8, decoder_channels=64, num_bits=48,
    attenuation="jnd", scale_channels=False, scaling_i=1, scaling_w=1.5
)

decoder = HiddenDecoder(
    num_blocks=params.decoder_depth,
    num_bits=params.num_bits,
    channels=params.decoder_channels
)
encoder = HiddenEncoder(
    num_blocks=params.encoder_depth,
    num_bits=params.num_bits,
    channels=params.encoder_channels
)
attenuation = JND(preprocess=UNNORMALIZE_IMAGENET) if params.attenuation == "jnd" else None
encoder_with_jnd = EncoderWithJND(
    encoder, attenuation, params.scale_channels, params.scaling_i, params.scaling_w
)

# %%
ckpt_path = "ckpts/hidden_replicate.pth"

state_dict = torch.load(ckpt_path, map_location='cpu')['encoder_decoder']
encoder_decoder_state_dict = {k.replace('module.', ''): v for k, v in state_dict.items()}
encoder_state_dict = {k.replace('encoder.', ''): v for k, v in encoder_decoder_state_dict.items() if 'encoder' in k}
decoder_state_dict = {k.replace('decoder.', ''): v for k, v in encoder_decoder_state_dict.items() if 'decoder' in k}

encoder.load_state_dict(encoder_state_dict)
decoder.load_state_dict(decoder_state_dict)

encoder_with_jnd = encoder_with_jnd.to(device).eval()
decoder = decoder.to(device).eval()

# %%
img = Image.open("/raid/home/ashhar21137/watermarking2/original_images/Image_2024.jpg").convert('RGB')
img = img.resize((512, 512), Image.BICUBIC)
img_pt = default_transform(img).unsqueeze(0).to(device)

# create message
random_msg = False
if random_msg:
    msg_ori = torch.randint(0, 2, (1, params.num_bits), device=device).bool().to(device) # b k
else:
    msg_ori = torch.Tensor(str2msg("111010110101000001010111010011010100010000100111")).unsqueeze(0).to(device)
msg = 2 * msg_ori.type(torch.float) - 1 # b k
# encode
img_w = encoder_with_jnd(img_pt, msg)
clip_img = torch.clamp(UNNORMALIZE_IMAGENET(img_w), 0, 1)
clip_img = torch.round(255 * clip_img)/255
clip_img = transforms.ToPILImage()(clip_img.squeeze(0).cpu())
diff = np.abs(np.asarray(img).astype(int) - np.asarray(clip_img).astype(int)) / 255 * 10

# %%
# decode
ft = decoder(default_transform(clip_img).unsqueeze(0).to(device))
decoded_msg = ft > 0 # b k -> b k
accs = (~torch.logical_xor(decoded_msg, msg_ori)) # b k -> b k
print(f"Message: {msg2str(msg_ori.squeeze(0).cpu().numpy())}")
print(f"Decoded: {msg2str(decoded_msg.squeeze(0).cpu().numpy())}")
print(f"Bit Accuracy: {accs.sum().item() / params.num_bits}")
# Out:
# Message: 111010110101000001010111010011010100010000100111
# Decoded: 111010110101000101010111000001010100001000100111
# Bit Accuracy: 0.8958333333333334

# %%
input_dir = "/raid/home/ashhar21137/watermarking2/original_images"
output_dir = "/raid/home/ashhar21137/watermarking3/stable_sig_watermarked"
results_file = "initial_stable_sig_results.json"
params = {'num_bits': 48}  # Example, adjust accordingly

# %%
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# %%
import json

# %%
image_files = [f for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]

results_data = []

for img_file in image_files:
    img_path = os.path.join(input_dir, img_file)
    img = Image.open(img_path).convert('RGB')
    img = img.resize((512, 512), Image.BICUBIC)
    img_pt = default_transform(img).unsqueeze(0).to(device)

    # create message
    random_msg = False
    if random_msg:
        msg_ori = torch.randint(0, 2, (1, params['num_bits']), device=device).bool().to(device)  # b k
    else:
        msg_ori = torch.Tensor(str2msg("111010110101000001010111010011010100010000100111")).unsqueeze(0).to(device)
    msg = 2 * msg_ori.type(torch.float) - 1  # b k

    # encode
    img_w = encoder_with_jnd(img_pt, msg)
    clip_img = torch.clamp(UNNORMALIZE_IMAGENET(img_w), 0, 1)
    clip_img = torch.round(255 * clip_img) / 255
    clip_img = transforms.ToPILImage()(clip_img.squeeze(0).cpu())
    
    # save watermarked image
    watermarked_img_path = os.path.join(output_dir, img_file)
    clip_img.save(watermarked_img_path)

    # decode
    ft = decoder(default_transform(clip_img).unsqueeze(0).to(device))
    decoded_msg = ft > 0  # b k -> b k
    accs = (~torch.logical_xor(decoded_msg, msg_ori))  # b k -> b k
    bit_accuracy = accs.sum().item() / params['num_bits']
    detection_result = 1 if bit_accuracy > 0.90 else 0
    
    # store results
    results_data.append({
        "image": img_file,
        "bit_accuracy": bit_accuracy,
        "detection_result": detection_result
    })
    print(f"Processed {img_file}: Bit Accuracy = {bit_accuracy:.4f}, Detection Result = {detection_result}")

# Save results to JSON file
with open(results_file, 'w') as json_file:
    json.dump(results_data, json_file, indent=4)

print("Watermarking completed. Results saved to", results_file)
# Out:
# Processed Image_79481.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_96557.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_280260.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_62279.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_170558.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_215481.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_520208.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_95989.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_504616.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_309322.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_239728.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_341550.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_405613.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_441488.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_420721.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_18885.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_399956.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_93785.jpg: Bit Accuracy = 0.9375, Detection Result = 1
# Processed Image_570246.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_262845.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_49183.jpg: Bit Accuracy = 0.9583, Detection Result = 1
# Processed Image_142088.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_394326.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_524068.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_352884.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_199628.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_160559.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_57870.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_398494.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_241364.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_84427.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_393493.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_483008.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_469605.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_348850.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_387083.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_77375.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_122108.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_540162.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_19380.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_44404.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_345781.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_405207.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_153946.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_457732.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_153674.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_472925.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_388754.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_170850.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_384029.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_62604.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_570608.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_317237.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_299411.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_109424.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_581674.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_239811.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_318189.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_278347.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_90570.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_374114.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_505126.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_8649.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_145179.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_66514.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_462559.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_4428.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_210932.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_257350.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_122688.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_377694.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_438422.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_161919.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_354444.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_287541.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_556801.jpg: Bit Accuracy = 0.8542, Detection Result = 0
# Processed Image_186233.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_95133.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_496939.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_71631.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_371029.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_259446.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_55627.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_334080.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_150867.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_470072.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_181104.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_559527.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_209967.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_444546.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_409513.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_165499.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_351430.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_36633.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_147303.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_474882.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_318574.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_222016.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_236772.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_486320.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_551125.jpg: Bit Accuracy = 0.9583, Detection Result = 1
# Processed Image_70868.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_378710.jpg: Bit Accuracy = 0.9583, Detection Result = 1
# Processed Image_536587.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_167613.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_392136.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_287927.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_217306.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_560459.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_496283.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_212091.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_483751.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_223726.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_560628.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_108627.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_246804.jpg: Bit Accuracy = 0.9583, Detection Result = 1
# Processed Image_365363.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_64460.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_225750.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_446014.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_157032.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_96997.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_302389.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_574001.jpg: Bit Accuracy = 0.9583, Detection Result = 1
# Processed Image_525589.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_280980.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_316676.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_412535.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_445528.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_576757.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_313932.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_477797.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_98760.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_513541.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_136461.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_85685.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_356702.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_424102.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_467311.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_540988.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_301778.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_388911.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_409382.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_292835.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_311914.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_492386.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_69675.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_189993.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_265709.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_269829.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_326511.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_353139.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_309093.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_277854.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_546451.jpg: Bit Accuracy = 0.8958, Detection Result = 0
# Processed Image_344806.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_413746.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_279108.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_576801.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_246446.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_520950.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_155845.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_448698.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_2024.jpg: Bit Accuracy = 0.8958, Detection Result = 0
# Processed Image_357684.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_101418.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_219025.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_547471.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_70000.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_289019.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_270912.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_485894.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_535786.jpg: Bit Accuracy = 0.9583, Detection Result = 1
# Processed Image_147016.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_343322.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_412198.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_77806.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_168194.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_303291.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_491269.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_530683.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_172899.jpg: Bit Accuracy = 0.9375, Detection Result = 1
# Processed Image_267688.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_523617.jpg: Bit Accuracy = 0.7292, Detection Result = 0
# Processed Image_426038.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_214704.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_497616.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_179620.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_42493.jpg: Bit Accuracy = 0.9792, Detection Result = 1
# Processed Image_62426.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_543877.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_160163.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_167603.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_218956.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_147170.jpg: Bit Accuracy = 0.8333, Detection Result = 0
# Processed Image_283524.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_37015.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_213546.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_528906.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Processed Image_454325.jpg: Bit Accuracy = 1.0000, Detection Result = 1
# Watermarking completed. Results saved to initial_stable_sig_results.json
